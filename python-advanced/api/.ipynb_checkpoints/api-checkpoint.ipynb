# %%
import requests

# %% [markdown]
# <b> We are using {JSON} Placeholder for practice which provides Free fake and reliable API for testing and prototyping. </b>

# %%
url='https://jsonplaceholder.typicode.com/posts'

response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# | Status Code | Meaning | Simple explanation |
# |---|---|---|
# | **200** | OK | ✅ Request successful |
# | **201** | Created | ✅ Something was created |
# | **400** | Bad Request | ❌ Your request was incorrect |
# | **401** | Unauthorized | 🔐 Authentication is missing/invalid |
# | **403** | Forbidden | 🚫 You don't have permission |
# | **404** | Not Found | ❌ Resource doesn't exist |
# | **500** | Internal Server Error | 💥 Something went wrong on server |

# %%
response.json() #gets the content
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
#its a good practice to do 
if response.status_code==200: 
    data=response.json()
    print(data[0])
else:
    print("Failed to retrive data")
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
#Url of the api end point 
url='https://jsonplaceholder.typicode.com/posts'

#data to send in the POST request 
data={
    "title" : "foo",
    "body" : "bar", 
    "userId" : 1
}

response=requests.post(url,json=data)
response.status_code
# Out:
# 201

# %% [markdown]
# #### Common Status Codes
#
# 1. 200: OK (The request was successful).
# 1. 201: Created (The resource was successfully created).
# 1. 400: Bad Request (The server could not understand the request).
# 1. 401: Unauthorized (Authentication is required).
# 1. 404: Not Found (The requested resource could not be found).
# 1. 500: Internal Server Error (The server encountered an error).

# %%
#Checking the status code of the response
if response.status_code == 201: 
    #parsing the JSON ddata
    created_post=response.json()
    #printing created post 
    print(created_post)
else:
    print("Failed to creaate data")
# Out:
# {'title': 'foo', 'body': 'bar', 'userId': 1, 'id': 101}

# %%
if response.status_code == 201: 
    #parsing the JSON ddata
    created_post=response.json()
    #printing created post 
    print(created_post)
elif response.status_code==404:
    print("Resource not found")
else:
    print("Failed to creaate data")
# Out:
# {'title': 'foo', 'body': 'bar', 'userId': 1, 'id': 101}

# %%
url='https://jsonplaceholder.typicode.com/posts'

param={
    "userId" : 1
} # it means just focus on userid 1

response=requests.get(url,params=param)

if response.status_code==200:
    print(response.json())

else:
    print("Failed to retrive data")
# Out:
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic
# ...

# %%
import requests

# URL of the API endpoint
url = "https://api.coindesk.com/v1/bpi/currentprice.json"

# Sending a GET request
response = requests.get(url)

# Checking the status code of the response
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Failed to retrieve data")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
url='https://api.currencyapi.com/v3/latest?apikey=cur_live_RFckDHmWd74QuHTVYnYl64FQAQ64wRE7OKre7Nni&currencies=EUR%2CUSD%2CCAD%2CINR'

response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Failed to retrieve data")
# Out:
# {'meta': {'last_updated_at': '2026-09-16T23:59:59Z'}, 'data': {'CAD': {'code': 'CAD', 'value': 1.3988502428}, 'EUR': {'code': 'EUR', 'value': 0.871874113}, 'INR': {'code': 'INR', 'value': 96.0680099828}, 'USD': {'code': 'USD', 'value': 1}}}

# %%
for i,j in data['data'].items():
    print(f"{i} : {j['value']}")
# Out:
# CAD : 1.3988502428
# EUR : 0.871874113
# INR : 96.0680099828
# USD : 1

# %%
https://app.currencyapi.com/dashboard
