# %% [markdown]
# <h2 align="center" style="color:blue"> Python: List, Dict Comprehension Tutorial</h2>

# %%
numbers = [1,2,3,4,5]
sqr_numbers = []

for n in numbers:
    sqr_numbers.append(n*n)
print(sqr_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %%
sqr_numbers = [n*n for n in numbers]
sqr_numbers
# Out:
# [1, 4, 9, 16, 25]

# %%
#with 2 condn
[x for x in range(10) if x % 2 == 0 if x % 3 != 0]
# Out:
# [2, 4, 8]

# %% [markdown]
# ### List Comprehension Offers Better Performance

# %%
import time

long_list = range(10000000)
sqr_list = []

start = time.time()
for n in long_list:
    sqr_list.append(n*n)
end = time.time()
print("Time taken by for loop:", (end-start))
# Out:
# Time taken by for loop: 2.5463755130767822

# %%
start = time.time()
sqr_list = [n*n for n in long_list]
end = time.time()
print("Time taken by list comprehension:", (end-start))
# Out:
# Time taken by list comprehension: 1.4109601974487305

# %% [markdown]
# ### List Comprehension With Two Lists

# %%
price = [100,120,80,50]
earning_per_share = [9, 15, 40, 2]

pe=[p/e for p in price and e in earning_per_share]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 price = [100,120,80,50]
#       2 earning_per_share = [9, 15, 40, 2]
# ----> 4 pe=[p/e for p in price and e in earning_per_share]
#
# NameError: name 'e' is not defined

# %%
price = [100,120,80,50]
earning_per_share = [9, 15, 40, 2] 
pe = [p/e for p,e in zip(price,earning_per_share)]
pe
# Out:
# [11.11111111111111, 8.0, 2.0, 25.0]

# %%
price = [100,120,80,50]
earning_per_share = [9, 0, 40, 2]

pe = [p/e for p, e in zip(price, earning_per_share)]
pe
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 price = [100,120,80,50]
#       2 earning_per_share = [9, 0, 40, 2]
# ----> 4 pe = [p/e for p, e in zip(price, earning_per_share)]
#       5 pe
#
# Cell In[5], line 4, in <listcomp>(.0)
#       1 price = [100,120,80,50]
#       2 earning_per_share = [9, 0, 40, 2]
# ----> 4 pe = [p/e for p, e in zip(price, earning_per_share)]
#       5 pe
#
# ZeroDivisionError: division by zero

# %%
price = [100,120,80,50]
earning_per_share = [9, 0, 40, 2]

pe=[if e!=0 p/e for p, e in zip(price, earning_per_share) else "undefined" ]
pe
# Out:
#   Cell In[12], line 4
#     pe=[if e!=0 p/e for p, e in zip(price, earning_per_share) else "undefined" ]
#         ^
# SyntaxError: invalid syntax

# %%
price = [100,120,80,50]
earning_per_share = [9, 0, 40, 2]

pe = [p/e if e!=0 else -1 for p, e in zip(price, earning_per_share)]
pe
# Out:
# [11.11111111111111, -1, 2.0, 25.0]

# %% [markdown]
# ### Calling a Function in List Comprehension

# %%
words = ["apple", "banana", "cherry", "date"]
lengths = [len(word) for word in words]
print(lengths)
# Out:
# [5, 6, 6, 4]

# %% [markdown]
# **Below code shows how you can give a discount to those folks with greater than 100 $ purchase**

# %%
prices = [120, 99, 150, 80, 200]
discounted_prices = [0.9*p if p>100 else p for p in prices]
print(discounted_prices)
# Out:
# [108.0, 99, 135.0, 80, 180.0]

# %% [markdown]
# ### Dictionary Comprehension

# %%
names = ["Alice", "Bob", "Charlie"]
ages = [25, 30, 35]
name_age_dict = {name : age for name,age in zip(names,ages)}
print(name_age_dict)
# Out:
# {'Alice': 25, 'Bob': 30, 'Charlie': 35}

# %%
names = ["Alice", "Bob", "Charlie"]
ages = [25, 30, 35]
name_age_dict = {names[i]:ages[i] for i in range(len(names))}
print(name_age_dict)
# Out:
# {'Alice': 25, 'Bob': 30, 'Charlie': 35}

# %% [markdown]
# ### Set Comprehension

# %%
transactions = [
    {'customer_name': "Mira", "amount": 56, "date": "2024-08-01"},
    {'customer_name': "Mira", "amount": 12.3, "date": "2024-09-05"},
    {'customer_name': "Mohan", "amount": 21, "date": "2024-09-03"},
    {'customer_name': "Mohan", "amount": 36.8, "date": "2024-09-10"},
    {'customer_name': "Lucy", "amount": 66.3, "date": "2024-09-10"}
]

# %%
customers = set()

for trans in transactions:
    customers.add(trans['customer_name'])
    
customers
# Out:
# {'Lucy', 'Mira', 'Mohan'}

# %%
customers = {t['customer_name'] for t in transactions}
customers
# Out:
# {'Lucy', 'Mira', 'Mohan'}
