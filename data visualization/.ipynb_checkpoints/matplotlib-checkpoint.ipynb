# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
x_axis=np.linspace(0,5,11)
x_axis
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y_axis=x_axis**2
y_axis
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x_axis,y_axis)
plt.title("Hello")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %%
plt.plot(x_axis, y_axis, color="red", linestyle="--", marker="o")

# %%
"""
r = red 
o = circle marker
-- = dashed line
"""


plt.plot(x_axis, y_axis, "ro--")

# %%
"""
Things you CANNOT normally put in plt.plot()

plt.plot(x_axis, y_axis, xlabel="X Axis")   ❌
plt.plot(x_axis, y_axis, ylabel="Y Axis")   ❌
plt.plot(x_axis, y_axis, title="Hello")     ❌

Instead:

plt.plot(x_axis, y_axis)

plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Hello")
"""
# Out:
# '\nThings you CANNOT normally put in plt.plot()\n\nplt.plot(x_axis, y_axis, xlabel="X Axis")   ❌\nplt.plot(x_axis, y_axis, ylabel="Y Axis")   ❌\nplt.plot(x_axis, y_axis, title="Hello")     ❌\n\nInstead:\n\nplt.plot(x_axis, y_axis)\n\nplt.xlabel("X Axis")\nplt.ylabel("Y Axis")\nplt.title("Hello")\n'

# %%
fig = plt.figure(figsize=(20,8),dpi = 100)
axis1 = fig.add_axes([0.1,0.1,.4,.8])
axis1.plot(x_axis,y_axis)
axis2 = fig.add_axes([0.3,0.4,.3,.3])
axis2.plot(x_axis,y_axis)

# %%
plt.scatter(x_axis,y_axis)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 8., 10.,  4., 13., 14.,  8., 10.,  7., 14., 12.]),
#  array([  2. , 101.5, 201. , 300.5, 400. , 499.5, 599. , 698.5, 798. ,
#         897.5, 997. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x_axis)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d6c942ae90>,
#   <matplotlib.lines.Line2D at 0x2d6c942afd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2d6c942b110>,
#   <matplotlib.lines.Line2D at 0x2d6c942b250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2d6c942ad50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d6c942b390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d6c942b4d0>],
#  'means': []}

# %%
#Saving Plots

fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x_axis,y_axis)
plt.savefig("basicplot.png")

# %% [markdown]
# Working with Images

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('images.jpg')

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(6047.5), np.float64(4023.5), np.float64(-0.5))

# %%
cropped_img = img[50:200, 100:300]  # crop: rows 50-200, cols 100-300
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %%
xaxis = np.linspace(0,5,11)
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
