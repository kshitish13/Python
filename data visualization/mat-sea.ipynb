# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached packaging-26.3-py3-none-any.whl.metadata (3.5 kB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    -------------------- ------------------- 5.0/9.5 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 25.4 MB/s  0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 20.8 MB/s  0:00:00
# ...
# Using cached packaging-26.3-py3-none-any.whl (129 kB)
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 7.2/7.2 MB 38.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
# ...

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df_sales=pd.read_excel("linechart.xlsx")
df_sales.head()
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8

# %%
df_sales.shape
# Out:
# (6, 4)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_sales["Quarter"],df_sales['Fridge'])

# %%
plt.plot(df_sales["Quarter"],df_sales['Fridge'],color="blue")
plt.plot(df_sales["Quarter"],df_sales['Dishwasher'],color="green")
plt.plot(df_sales["Quarter"],df_sales['Washing Machine'],color="orange")

# %%
plt.figure(figsize=(12,4))
plt.plot(df_sales["Quarter"],df_sales['Fridge'],color="blue")
plt.plot(df_sales["Quarter"],df_sales['Dishwasher'],color="green")
plt.plot(df_sales["Quarter"],df_sales['Washing Machine'],color="orange") 
plt.title("Product Sales")
plt.ylabel("Revenue")
plt.xlabel("Financial Quarter")
plt.legend()
plt.show()
# Out:
# C:\Users\kshit\AppData\Local\Temp\ipykernel_12384\2783114768.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Pie Chart

# %%
total_sales=df_sales[['Fridge','Dishwasher','Washing Machine']].sum()
total_sales
# Out:
# Fridge             80.9
# Dishwasher         53.0
# Washing Machine    45.6
# dtype: float64

# %%
plt.pie(total_sales,labels=total_sales.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x21415f75310>,
# ...
#  [Text(0.1697005203681718, 1.0868310509857417, 'Fridge'),
#   Text(-0.8966590959823768, -0.6371832276449741, 'Dishwasher'),
#   Text(0.7678855526316927, -0.7876241350158842, 'Washing Machine')])

# %% [markdown]
# plt.pie(total_sales,labels=total_sales.index,autopct="%1.1f%%")

# %%
#explode
plt.pie(total_sales,labels=total_sales.index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x214160a1090>,
# ...
#  [Text(0.1697005203681718, 1.0868310509857417, 'Fridge'),
#   Text(-0.8966590959823768, -0.6371832276449741, 'Dishwasher'),
#   Text(0.7678855526316927, -0.7876241350158842, 'Washing Machine')],
#  [Text(0.09256392020082098, 0.5928169369013137, '45.1%'),
#   Text(-0.48908677962675096, -0.3475544878063495, '29.5%'),
#   Text(0.4188466650718323, -0.42961316455411863, '25.4%')])

# %% [markdown]
# # Bar Chart

# %%
df_sales.plot(kind="bar", x="Quarter")

plt.xticks(rotation=45)
plt.show()
