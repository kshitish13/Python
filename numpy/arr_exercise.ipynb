# %%
import numpy as np

# %% [markdown]
# Valid sudoku

# %%
s=np.array([
    [5,3,4,6,7,8,9,1,2],
    [6,7,2,1,9,5,3,4,8],
    [1,9,8,3,4,2,5,6,7],

    [8,5,9,7,6,1,4,2,3], 
    [4,2,6,8,5,3,7,9,1], 
    [7,1,3,9,2,4,8,5,6], 

    [9,6,1,5,3,7,2,8,4], 
    [2,8,7,4,1,9,6,3,5], 
    [3,4,5,2,8,6,1,7,9]
])

# %% [markdown]
# General Question

# %%
#Columns : [Age, Math marks, Science Marks]
data=np.array([
    [18,85,78], #student 1
    [19,92,88], #student 2
    [17,76,95], #student 3
    [18,65,70], #student 4
    [20,90,85]  #student 5
])

# %%
data.shape
# Out:
# (5, 3)

# %%
#Find the average age of students
age=data[0:,0]
age
# Out:
# array([18, 19, 17, 18, 20])

# %%
age.mean()
# Out:
# np.float64(18.4)

# %%
#Extract maths marks of all stuents
math=data[0:,1]
math
# Out:
# array([85, 92, 76, 65, 90])

# %%
#Find the highest science mark 
sci = data[0:,-1]

sci
# Out:
# array([78, 88, 95, 70, 85])

# %%
sci.max()
# Out:
# np.int64(95)

# %%
np.max(data[:,2])
# Out:
# np.int64(95)

# %%
#Get the details of students who got more than 90 in maths
data[:,1]>90
# Out:
# array([False,  True, False, False, False])

# %%
data[data[:,1]>90]
# Out:
# array([[19, 92, 88]])

# %%
#Increase the math marks of all students by 5
data[:,1]+=5
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 70],
#        [20, 95, 85]])

# %%
#Find how many students are younger than 19
data[data[:,0]<19]
# Out:
# array([[18, 90, 78],
#        [17, 81, 95],
#        [18, 70, 70]])

# %%
#Calculate the average marks in each subject (clomn wise mean)
avg=np.array([np.mean(data[:,1]),np.mean(data[:,2])])
avg
# Out:
# array([86.6, 83.2])

# %%
 np.mean(data[:,1:],axis=0) #axis=0 means col wise and 1 is for row wise
# Out:
# array([86.6, 83.2])

# %%
#Get data of students who got at least 80 in both subjects
data[(data[:,1] & data[:,2])>=80]
# Out:
# array([[17, 81, 95],
#        [20, 95, 85]])

# %%
#Replace all science marks < 75 with 0
data[:,2]<75.replace(0)
# Out:
#   Cell In[60], line 2
#     data[:,2]<75.replace(0)
#                 ^
# SyntaxError: invalid decimal literal

# %%
data[data[:,2]<75]=0
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [ 0,  0,  0],
#        [20, 95, 85]])

# %%
data[:,2][data[:,2]<75]=0
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70,  0],
#        [20, 95, 85]])
