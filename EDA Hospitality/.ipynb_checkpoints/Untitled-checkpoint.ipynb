# %%
import pandas as pd

# %%
df_bookings=pd.read_csv("datasets/fact_bookings.csv")
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings['room_category'].unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings['booking_platform'].unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings[df_bookings['booking_platform']=='makeyourtrip']
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 10      May012216558RT111        16558     29-04-22      1/5/2022
# 12      May012216558RT113        16558     26-04-22      1/5/2022
# 20       May012216558RT23        16558    10/4/2022      1/5/2022
# 28      May012216558RT211        16558     30-04-22      1/5/2022
# 34      May012216558RT217        16558     29-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134561  Jul312217564RT212        17564     31-07-22      31-07-22
# 134566  Jul312217564RT217        17564     30-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 10          7/5/2022        1.0           RT1     makeyourtrip            5.0
# ...

# %%
df_bookings['booking_platform'].value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings['booking_platform'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings['booking_platform'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings['revenue_generated'].min(),df_bookings['revenue_generated'].max()
# Out:
# (6500, 28560000)

# %%
df_date = pd.read_csv('datasets/dim_date.csv')
df_hotels = pd.read_csv('datasets/dim_hotels.csv')
df_rooms = pd.read_csv('datasets/dim_rooms.csv')
df_agg_bookings = pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_hotels['category'].value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels['city'].value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels['city'].value_counts().sort_values()
# Out:
# city
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: count, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
#no of guest cant be less than 1 

df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
#as there are vey less who has -ve no  of guest we can drop them
# Remove bookings where the number of guests is zero or negative
df_bookings = df_bookings[df_bookings["no_guests"] > 0]

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
#max is too high for one 
#you go to bussiness manager and ask for whats the highest revenue that can be generated
#or we can use 3 std dev techique to remove outlier 
#ie if any value is morw than 3 std dev away from mean its an outlier 

avg, std=df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()
avg,std
# Out:
# (np.float64(15378.036937686695), 93040.15493143328)

# %%
higher_limit=avg+3*std
higher_limit
# Out:
# np.float64(294498.50173198653)

# %%
lower_limit=avg-3*std
lower_limit
#we dont care about lower limit as it cant be -ve
# Out:
# np.float64(-263742.4278566132)

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
#drop 
df_bookings=df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
#now lets clean for revenue realized 
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
#lets see if max is valid or noct
higher_limit=df_bookings.revenue_realized.mean()+3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# np.float64(33479.3586618449)

# %%
#we dont want use 3 std dev directly here as it may be valid in some cases
#but lets see with 3 std dev 

df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
#here we can se there are so many rows (1299) 
#and all are RT4 so it might be valid
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
#we can see its presidential room so it might be costly
#lets see for this rt4 rooms

df_bookings[df_bookings.room_category=="RT4"].revenue_realized
# Out:
# 47        10640
# 48        26600
# 49        10640
# 137       38760
# 138       12920
#           ...
# 134584    32300
# 134585    32300
# 134587    12920
# 134588    32300
# 134589    12920
# Name: revenue_realized, Length: 16071, dtype: int64

# %%
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
df_bookings.isnull()
# Out:
#         booking_id  property_id  booking_date  check_in_date  checkout_date  \
# 1            False        False         False          False          False
# 4            False        False         False          False          False
# 5            False        False         False          False          False
# 6            False        False         False          False          False
# 7            False        False         False          False          False
# ...            ...          ...           ...            ...            ...
# 134584       False        False         False          False          False
# 134585       False        False         False          False          False
# 134587       False        False         False          False          False
# 134588       False        False         False          False          False
# 134589       False        False         False          False          False
#
# ...

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# # Data Transformation

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings['occupency_percent']=df_agg_bookings.successful_bookings/df_agg_bookings.capacity
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupency_percent
# 0           0.833333
# 1           0.933333
# 2           0.766667
# 3           1.578947
# 4           0.947368

# %%
df_agg_bookings['occupency_percent']=df_agg_bookings.occupency_percent.apply(lambda x : round(x*100,2))
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupency_percent
# 0              83.33
# 1              93.33
# 2              76.67
# 3             157.89
# 4              94.74

# %% [markdown]
# # Insights Generation
#  * Ad Hoc analysis

# %% [markdown]
# <h4> 1. What is an average occupancy rate in each of the room categories?</h4>

# %%
df_agg_bookings.groupby('room_category')['occupency_percent'].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occupency_percent, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=df_agg_bookings.merge(df_rooms,left_on='room_category',right_on="room_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupency_percent room_id room_class
# 0              83.33     RT1   Standard
# 1              93.33     RT1   Standard
# 2              76.67     RT1   Standard
# 3             157.89     RT1   Standard
# 4              94.74     RT1   Standard

# %%
df.groupby("room_class")['occupency_percent'].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occupency_percent, dtype: float64

# %%
df.drop("room_id",axis=1,inplace=True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupency_percent room_class
# 0              83.33   Standard
# 1              93.33   Standard
# 2              76.67   Standard
# 3             157.89   Standard
# 4              94.74   Standard

# %% [markdown]
# **2. Print average occupancy rate per city**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupency_percent room_class
# 0              83.33   Standard
# 1              93.33   Standard
# 2              76.67   Standard
# 3             157.89   Standard
# 4              94.74   Standard

# %%
df=df.merge(df_hotels,on='property_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupency_percent room_class  property_name  category       city
# 0              83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1              93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2              76.67   Standard   Atliq Palace  Business  Bangalore
# 3             157.89   Standard   Atliq Grands    Luxury     Mumbai
# 4              94.74   Standard   Atliq Grands    Luxury      Delhi

# %%
df.groupby('city')['occupency_percent'].mean()
# Out:
# city
# Bangalore    56.594207
# Delhi        61.606467
# Hyderabad    58.144651
# Mumbai       57.936305
# Name: occupency_percent, dtype: float64

# %%
df.groupby('city')['occupency_percent'].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **3. When was the occupancy better? Weekday or Weekend?**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df=df.merge(df_date,left_on="check_in_date",right_on="date")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#    occupency_percent room_class property_name  category       city       date  \
# 0              51.72    Premium  Atliq Palace  Business  Bangalore  10-May-22
# 1              63.33   Standard    Atliq City  Business  Hyderabad  10-May-22
# 2              60.00   Standard     Atliq Bay    Luxury  Bangalore  10-May-22
# 3              53.33   Standard  Atliq Palace  Business  Bangalore  10-May-22
# 4              57.89   Standard  Atliq Grands    Luxury     Mumbai  10-May-22
#
#    mmm yy week no  day_type
# ...

# %%
df.drop("date",axis=1,inplace=True)
df.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
#
#    occupency_percent room_class property_name  category       city  mmm yy  \
# 0              51.72    Premium  Atliq Palace  Business  Bangalore  May 22
# 1              63.33   Standard    Atliq City  Business  Hyderabad  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday

# %%
df.groupby('day_type')['occupency_percent'].mean()
# Out:
# day_type
# weekeday    50.903780
# weekend     72.393432
# Name: occupency_percent, dtype: float64

# %% [markdown]
# **4: In the month of June, what is the occupancy for different cities**

# %%
df['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june=df[df['mmm yy']=='Jun 22']
df_june
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
# ...           ...           ...           ...                  ...       ...
# 4295        17562     30-Jun-22           RT4                    3       6.0
# 4296        19563     30-Jun-22           RT4                    3       6.0
# 4297        16560     30-Jun-22           RT4                    3       7.0
# 4298        19558     30-Jun-22           RT4                    3       7.0
# 4299        17561     30-Jun-22           RT4                    3       4.0
#
# ...

# %%
df_june.groupby('city')['occupency_percent'].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occupency_percent, dtype: float64

# %% [markdown]
# **5: We got new data for the month of august. Append that to existing data**

# %%
df_august = pd.read_csv("datasets/new_data_august.csv")
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#    occupency_percent
# 0             100.00
# 1              70.00
# 2              76.67

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occupency_percent'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occupency_percent', 'room_class', 'property_name',
#        'category', 'city', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_latest=pd.concat([df,df_august],ignore_index=True)
df_latest.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occupency_percent    room_class  property_name  category       city  \
# ...

# %% [markdown]
# 6. Print revenue realized per city

# %%
df_bookings.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920

# %%
df_bookings_all=df_bookings.merge(df_hotels,on='property_id')
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df.groupby('city')['revenue_realized'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df.groupby('city')['revenue_realized'].sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
#     244     if key not in self.obj:
# --> 245         raise KeyError(f"Column not found: {key}")
# ...
