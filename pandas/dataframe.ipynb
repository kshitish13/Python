# %%
import numpy as np 
import pandas as pd

# %%
#creating dataframe
data={
    'Name':['Kshitij','John','Jack'],
    'Age':[22,30,45],
    'City':['Bangalore','New York','Florida'],
    'Salary':[65000,70000,62000]
}

df=pd.DataFrame(data)
df
# Out:
#       Name  Age       City  Salary
# 0  Kshitij   22  Bangalore   65000
# 1     John   30   New York   70000
# 2     Jack   45    Florida   62000

# %%
data_list=[
    ['John',28,'New York',65000], 
    ['Peter Pan',29,'Berlin', 62000], 
    ['Linda', 42 ,'London',85000]
]
df2=pd.DataFrame(data_list)
df2
# Out:
#            0   1         2      3
# 0       John  28  New York  65000
# 1  Peter Pan  29    Berlin  62000
# 2      Linda  42    London  85000

# %%
col=["Name","Age","City","Salary"]
df2=pd.DataFrame(data_list,columns=col)
df2
# Out:
#         Name  Age      City  Salary
# 0       John   28  New York   65000
# 1  Peter Pan   29    Berlin   62000
# 2      Linda   42    London   85000

# %% [markdown]
# Selection and indexing of columns

# %%
df2["Name"]
# Out:
# 0         John
# 1    Peter Pan
# 2        Linda
# Name: Name, dtype: object

# %%
df2[["Name","City"]]
# Out:
#         Name      City
# 0       John  New York
# 1  Peter Pan    Berlin
# 2      Linda    London

# %% [markdown]
# Creating new column

# %%
df2["Designation"]=["Doc","Eng.","Doc"]
df2
# Out:
#         Name  Age      City  Salary Designation
# 0       John   28  New York   65000         Doc
# 1  Peter Pan   29    Berlin   62000        Eng.
# 2      Linda   42    London   85000         Doc

# %% [markdown]
# Removing Column

# %%
df2.drop("Designation")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df2.drop("Designation")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df2.drop("Designation",axis=1)

# %%
df2
# Out:
#         Name  Age      City  Salary Designation
# 0       John   28  New York   65000         Doc
# 1  Peter Pan   29    Berlin   62000        Eng.
# 2      Linda   42    London   85000         Doc

# %%
df2.drop("Designation",axis=1,inplace=True)
df2
# Out:
#         Name  Age      City  Salary
# 0       John   28  New York   65000
# 1  Peter Pan   29    Berlin   62000
# 2      Linda   42    London   85000

# %% [markdown]
# selecting rows

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,2]]
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 2  Linda   42    London   85000

# %%
df2.iloc[2]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 2, dtype: object

# %% [markdown]
# select subset of rows and columns

# %%
df2.loc[[0,1]]
# Out:
#         Name  Age      City  Salary
# 0       John   28  New York   65000
# 1  Peter Pan   29    Berlin   62000

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1    Berlin   62000

# %% [markdown]
# Conditional selection

# %%
#age>30 
df2["Age"]>30
# Out:
# 0    False
# 1    False
# 2     True
# Name: Age, dtype: bool

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 2  Linda   42  London   85000

# %%
#age>25 and city=londom

df2[(df2["Age"]>25) & (df2["City"]=="London")]
# Out:
#     Name  Age    City  Salary
# 2  Linda   42  London   85000
